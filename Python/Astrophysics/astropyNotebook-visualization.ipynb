# %% [markdown]
# OBTENER IMAGEN DE SLOAN

# %%
import matplotlib.pyplot as pl
import numpy as np
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
Name='M 51'
Fuente = SkyCoord.from_name(Name)  # poner nombre fuete y te busca en SESAME las coordenadas (hay que tener conexión a internet)
print('Las cooredanadas de', Name,'son ', Fuente)  # nos da coordenadas ecuatoriales
# Out:
# Las cooredanadas de M 51 son  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 202.469575,  47.1952583)>

# %%
# si no ponerlas a mano, indicando unidades *u.units
#crab = SkyCoord(299.87*u.deg, 40.73*u.deg, frame='icrs')

# %%
# PYTHON Y SDSS (survey de galaxias) NOS PERMITE BAJARNOS DIRECTAMENTE LAS IMAGENES CORTADAS 
from urllib.parse import urlencode
from urllib.request import urlretrieve
from IPython.display import Image

# %%
im_size = 12*u.arcmin # get a 12 arcmin square
im_pixels = 1024
urlCutOut = 'http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx'
query_string = urlencode(dict(ra=Fuente.ra.deg,
                              dec=Fuente.dec.deg,
                              width=im_pixels, height=im_pixels,
                              scale=im_size.to(u.arcsec).value/im_pixels))
url = urlCutOut + '?' + query_string

# %%
urlretrieve(url, Name+'.jpg')
# Out:
# ('M 51.jpg', <http.client.HTTPMessage at 0x81ab8d780>)

# %% [markdown]
# IMAGEN obtenida de SDSS

# %%
Image(Name+'.jpg')

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
