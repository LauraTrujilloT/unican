# %% [markdown]
# # Graphs
# ### Important Plotting Functions
# `plot` $\rightarrow$ makes scatterplots or other R-objects plots.
#
# `abline` $\rightarrow$ add straight line
#
# `lines` $\rightarrow$ add connected line segments
#
# `segments` $\rightarrow$ add disconnected line segments
#
# `points` $\rightarrow$ add points
#
# `arrows` $\rightarrow$ add arrows
#
# `polygon` $\rightarrow$ add polygon
#
# `text` $\rightarrow$ add text labels
#
# `title` $\rightarrow$ add labels for x,y axes, title, subtitle, outer margin
#
# `axis` $\rightarrow$ modify axes ticks and labels

# %% [markdown]
# ## Exercise 5
# - Plot Ozone levels for each month
# - Plot Ozone levels for each day in May
# - Plot a multiple graph showing Ozone levels per Month and Day

# %%
data1 <- data.frame(airquality)
x <- data1$Ozone 
y <- data1$Month

# %%
png("a.png", width=800, height=400)
plot(y,x,col=rgb(0,0.5,0.5,0.8))
dev.off()
# Out:
# png
#   2

# %%
z <- data1[data1$Month==5,]

# %%
png("b.png", width=800, height=400)
plot(z$Day,z$Ozone,col="red", xlab="Days of May",ylab="Ozone Levels",pch=5)
dev.off()

#Another way : plot(Ozone[Month==5]~Day[Month==5])
# Out:
# png
#   2

# %%
par(mfrow=c(2,2))
#png("c.png",width=800, height=400)
plot(z$Day,z$Ozone,col="red", xlab="Days of May",ylab="Ozone Levels",pch=5)
plot(y,x,col=rgb(0,0.5,0.5,0.8), xlab="Month",ylab=)
# Out:
# plot without title

# %%
library(lattice)
fmonth=factor(airquality$Month) #data for one month and so on
xyplot(airquality$Ozone~airquality$Day|fmonth)
# Out:
# plot without title

# %% [markdown]
# ## Exercise 6
# - Do a 2 $\sigma$ clipping process over Ozone column values in airquality table.
# ```python
# x > 2 sigma #remove
# iterations = 10
# ```
#
# - Plot histogram and curves
